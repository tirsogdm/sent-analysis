# %% [markdown]
# ## Read in the data

# %%
from google.colab import drive
drive.mount('/content/drive')

def read_reviews(self, dir):
    f = open("/content/drive/My Drive/reviews_data")
    
    reviews = []
    for filename in os.listdir(dir):
        id, rating_str = filename.split("_")
        rating = int(rating_str.strip('.txt'))
        file_path = os.path.join(dir, filename)
        with open(file_path, 'r') as file:
            text = file.read()
        reviews.append((text, {"id": id, "rating": rating, "label": label}))
    return reviews

# %%
from transformers import BertTokenizer, BertForSequenceClassification

# Uncased
tokeniser = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

# Cased
tokeniser = BertTokenizer.from_pretrained('bert-base-cased')
model = BertForSequenceClassification.from_pretrained('bert-base-cased')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import pipeline
#
# ImportError: cannot import name 'pipeline' from 'transformers' (/Users/tirso/.pyenv/versions/3.10.5/envs/nlp-cw/lib/python3.10/site-packages/transformers/__init__.py)
